# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import nltk
from nltk import *
from nltk.text import Text
import string
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# %%
file_path = "ESConv.json"

with open(file_path, "r", encoding="utf-8") as file:
    dataset = json.load(file)

# %%
dataset[0]
# Out:
# {'dialog': [{'annotation': {}, 'content': 'Hello\n', 'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Question'},
#    'content': 'Hello, what would you like to talk about?',
#    'speaker': 'supporter'},
#   {'annotation': {},
#    'content': 'I am having a lot of anxiety about quitting my current job. It is too stressful but pays well\n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Question'},
#    'content': 'What makes your job stressful for you?',
#    'speaker': 'supporter'},
#   {'annotation': {'feedback': '5'},
#    'content': 'I have to deal with many people in hard financial situations and it is upsetting \n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Question'},
#    'content': 'Do you help your clients to make it to a better financial situation?',
#    'speaker': 'supporter'},
#   {'annotation': {},
#    'content': 'I do, but often they are not going to get back to what they want. Many people are going to lose their home when safeguards are lifted \n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Affirmation and Reassurance'},
#    'content': 'But you offer them a better future than what they have currently. It may not be what they wanted, but it helps them in the long run.',
#    'speaker': 'supporter'},
#   {'annotation': {'feedback': '5'},
#    'content': 'That is true but sometimes I feel like I should put my feelings and health first \n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Affirmation and Reassurance'},
#    'content': 'I can understand that. ',
#    'speaker': 'supporter'},
#   {'annotation': {'strategy': 'Question'},
#    'content': 'Is there another job that would pay you close to what you currently make?',
#    'speaker': 'supporter'},
#   {'annotation': {'feedback': '5'},
#    'content': 'Probably not. I was with the same company for a long time and I consistently get a bonus every year ',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Others'},
#    'content': "Is it possible to reframe how you look at your clients' dire financial situations?",
#    'speaker': 'supporter'},
#   {'annotation': {},
#    'content': 'I could try. It mostly gets to me at the end of the day \n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Information'},
#    'content': "Some people can't do what you do because they don't have the heart to give someone else bad news. The reality is though, someone needs to fill that role and you do help people",
#    'speaker': 'supporter'},
#   {'annotation': {'feedback': '4'},
#    'content': 'That is also true. Sometimes I wonder if it really is for me though  \n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Self-disclosure'},
#    'content': "I've had to deal with collections before when I was in  bad financial condition. The person on the other line was really helpful though. She was understanding,",
#    'speaker': 'supporter'},
#   {'annotation': {'strategy': 'Providing Suggestions'},
#    'content': 'It may not be for you. I think you should think about the pros and cons of keeping your position. It might make things clearer for you. ',
#    'speaker': 'supporter'},
#   {'annotation': {'feedback': '5'},
#    'content': 'That is true. Maybe I just need to sit down and really think about it \n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Restatement or Paraphrasing'},
#    'content': "I wouldn't stay if it really impacts your mental health in a negative way. Still, you may need to zoom out and see the bigger picture: that you provide a needed service and you do it compassionately",
#    'speaker': 'supporter'},
#   {'annotation': {},
#    'content': 'It really is a big decision \n',
#    'speaker': 'seeker'},
#   {'annotation': {},
#    'content': 'Thank you for the different perspective \n',
#    'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Affirmation and Reassurance'},
#    'content': 'No doubt, but you know in your heart what is right for you. ',
#    'speaker': 'supporter'},
#   {'annotation': {'feedback': '4'},
#    'content': 'That is true. Thanks again \n',
#    'speaker': 'seeker'},
#   {'annotation': {}, 'content': 'Bye\n', 'speaker': 'seeker'},
#   {'annotation': {'strategy': 'Affirmation and Reassurance'},
#    'content': "It's no problem. I hope you can make a decision about this situation and then be at peace with it",
#    'speaker': 'supporter'},
#   {'annotation': {'strategy': 'Others'},
#    'content': 'Ok, take care',
#    'speaker': 'supporter'}],
#  'emotion_type': 'anxiety',
#  'experience_type': 'Previous Experience',
#  'problem_type': 'job crisis',
#  'seeker_question1': 'Partner was very supportive',
#  'seeker_question2': 'More guidance in conversation or examples',
#  'situation': 'I hate my job but I am scared to quit and seek a new career.',
#  'supporter_question1': '',
#  'supporter_question2': '',
#  'survey_score': {'seeker': {'empathy': '5',
#    'final_emotion_intensity': '1',
#    'initial_emotion_intensity': '5',
#    'relevance': '5'},
#   'supporter': {'relevance': '5'}}}

# %%
# Extract conversations from the corpus (columns: index, dialog -> type(object -> list, dict))
corpus_data = []
for corpus in dataset:
    dialog = corpus['dialog']
    corpus_data.append(dialog)

df = pd.DataFrame({'Dialog': pd.Series(corpus_data)})

df
# Out:
#                                                  Dialog
# 0     [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1     [{'speaker': 'supporter', 'annotation': {'stra...
# 2     [{'speaker': 'supporter', 'annotation': {'stra...
# 3     [{'speaker': 'supporter', 'annotation': {'stra...
# 4     [{'speaker': 'supporter', 'annotation': {'stra...
# 5     [{'speaker': 'supporter', 'annotation': {'stra...
# 6     [{'speaker': 'supporter', 'annotation': {'stra...
# 7     [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 8     [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 9     [{'speaker': 'supporter', 'annotation': {'stra...
# 10    [{'speaker': 'supporter', 'annotation': {'stra...
# 11    [{'speaker': 'supporter', 'annotation': {'stra...
# 12    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 13    [{'speaker': 'supporter', 'annotation': {'stra...
# 14    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 15    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 16    [{'speaker': 'supporter', 'annotation': {'stra...
# 17    [{'speaker': 'supporter', 'annotation': {'stra...
# 18    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 19    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 20    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 21    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 22    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 23    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 24    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 25    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 26    [{'speaker': 'supporter', 'annotation': {'stra...
# 27    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 28    [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 29    [{'speaker': 'supporter', 'annotation': {'stra...
# ...                                                 ...
# 1270  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1271  [{'speaker': 'supporter', 'annotation': {'stra...
# 1272  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1273  [{'speaker': 'supporter', 'annotation': {'stra...
# 1274  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1275  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1276  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1277  [{'speaker': 'supporter', 'annotation': {'stra...
# 1278  [{'speaker': 'supporter', 'annotation': {'stra...
# 1279  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1280  [{'speaker': 'supporter', 'annotation': {'stra...
# 1281  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1282  [{'speaker': 'supporter', 'annotation': {'stra...
# 1283  [{'speaker': 'supporter', 'annotation': {'stra...
# 1284  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1285  [{'speaker': 'supporter', 'annotation': {'stra...
# 1286  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1287  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1288  [{'speaker': 'supporter', 'annotation': {'stra...
# 1289  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1290  [{'speaker': 'supporter', 'annotation': {'stra...
# 1291  [{'speaker': 'supporter', 'annotation': {'stra...
# 1292  [{'speaker': 'supporter', 'annotation': {'stra...
# 1293  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1294  [{'speaker': 'supporter', 'annotation': {'stra...
# 1295  [{'speaker': 'supporter', 'annotation': {'stra...
# 1296  [{'speaker': 'supporter', 'annotation': {'stra...
# 1297  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1298  [{'speaker': 'seeker', 'annotation': {}, 'cont...
# 1299  [{'speaker': 'supporter', 'annotation': {'stra...
#
# [1300 rows x 1 columns]

# %%
df.loc[2]
# Out:
# Dialog    [{'speaker': 'supporter', 'annotation': {'stra...
# Name: 2, dtype: object

# %%
# Extract the seeker conversations only from the corpus (columns: index, seeker dialog -> type(string))
seeker_df = pd.DataFrame(columns=['ConversationID', 'Seeker Dialog'])
for index, row in df.iterrows():
    dialog_list = row['Dialog']
    for dialog in dialog_list:
        if dialog['speaker'] == 'seeker':
            seeker_df = seeker_df.append({'ConversationID': index, 'Seeker Dialog': dialog['content']}, ignore_index=True)            
seeker_df
# Out:
#       ConversationID                                      Seeker Dialog
# 0                  0                                            Hello\n
# 1                  0  I am having a lot of anxiety about quitting my...
# 2                  0  I have to deal with many people in hard financ...
# 3                  0  I do, but often they are not going to get back...
# 4                  0  That is true but sometimes I feel like I shoul...
# 5                  0  Probably not. I was with the same company for ...
# 6                  0  I could try. It mostly gets to me at the end o...
# 7                  0  That is also true. Sometimes I wonder if it re...
# 8                  0  That is true. Maybe I just need to sit down an...
# 9                  0                     It really is a big decision \n
# 10                 0         Thank you for the different perspective \n
# 11                 0                      That is true. Thanks again \n
# 12                 0                                              Bye\n
# 13                 1           hello im looking for someone to talk to
# 14                 1                              im fine how are you\n
# 15                 1  thats great and no its not snowing its very co...
# 16                 1                     merry christmas to you also \n
# 17                 1  im having some issues with friends not actuall...
# 18                 1                                              yes\n
# 19                 1  yes their is no communication or interaction b...
# 20                 1                                       no friends\n
# 21                 1  when we where younger we all hung out all the ...
# 22                 1  it doesnt matter they still keep open communic...
# 23                 1  I believe its because I am the friend that has...
# 24                 1               no anything i owe i always pay back
# 25                 1             perhaps they are tired of being asked
# 26                 1                               no im not currently
# 27                 1  I also think sometimes to myself that they don...
# 28                 1                                 yes i dont qualify
# 29                 1                 I'm nervous about asking them why
# ...              ...                                                ...
# 19959           1297        I guess so. I want to have a good career.\n
# 19960           1297  I think it's a common problem, but I don't fee...
# 19961           1297  That's a good idea. I feel more productive in ...
# 19962           1297                                I might try that.\n
# 19963           1297     Yes, drinking water helps with concentration.
# 19964           1298                                            Hello\n
# 19965           1298          I am a little down today.  How are you?\n
# 19966           1298  My friends, who I also work with, are upset wi...
# 19967           1298                  I am sad that they are upset.  \n
# 19968           1298  I am going to miss them, but yes... I am happy...
# 19969           1298                         Honestly I don't know.  \n
# 19970           1298  I think I would feel alot better about it if m...
# 19971           1298                                            Maybe\n
# 19972           1298  Well we already have a group chat... we could ...
# 19973           1298  And lunch a few times a month would be nice, b...
# 19974           1298     Yes.  We won't even be awake at the same time.
# 19975           1298                              That is a good idea\n
# 19976           1298            I will at my new job but they do not.\n
# 19977           1298                                      Yes, thanks\n
# 19978           1299                                                 hi
# 19979           1299                                      i'm nereida\n
# 19980           1299               i am in disputed mod with my friends
# 19981           1299  I explained my personal problems but they are ...
# 19982           1299  They need more money from me, but i couldn't  ...
# 19983           1299  I want to speak with them because they are in ...
# 19984           1299  Yes, i want to do some moderate friendship wit...
# 19985           1299  I want to do some help to them but i don't do ...
# 19986           1299  Yes, some disappointments show us about real f...
# 19987           1299  Sure, it is my new way of relationship to me w...
# 19988           1299                            Great, thank you friend
#
# [19989 rows x 2 columns]

# %%
seeker_df['Seeker Dialog'].dtype # object
# Out:
# dtype('O')

# %%
print(type(seeker_df['Seeker Dialog'].iloc[0]))
# Out:
# <class 'str'>

# %%
print(seeker_df['Seeker Dialog'].apply(type).value_counts())
# Out:
# <class 'str'>    19989
# Name: Seeker Dialog, dtype: int64

# %%
def word_type(text):
    return len(set(text))

def lexical_diversity(text):
    return len(text) / word_type(text)

seeker_df['Lexical Diversity'] = seeker_df['Seeker Dialog'].apply(lexical_diversity)

# %%
seeker_df
# Out:
#       ConversationID                                      Seeker Dialog  \
# 0                  0                                            Hello\n
# 1                  0  I am having a lot of anxiety about quitting my...
# 2                  0  I have to deal with many people in hard financ...
# 3                  0  I do, but often they are not going to get back...
# 4                  0  That is true but sometimes I feel like I shoul...
# 5                  0  Probably not. I was with the same company for ...
# 6                  0  I could try. It mostly gets to me at the end o...
# 7                  0  That is also true. Sometimes I wonder if it re...
# 8                  0  That is true. Maybe I just need to sit down an...
# 9                  0                     It really is a big decision \n
# 10                 0         Thank you for the different perspective \n
# 11                 0                      That is true. Thanks again \n
# 12                 0                                              Bye\n
# 13                 1           hello im looking for someone to talk to
# 14                 1                              im fine how are you\n
# 15                 1  thats great and no its not snowing its very co...
# 16                 1                     merry christmas to you also \n
# 17                 1  im having some issues with friends not actuall...
# 18                 1                                              yes\n
# 19                 1  yes their is no communication or interaction b...
# 20                 1                                       no friends\n
# 21                 1  when we where younger we all hung out all the ...
# 22                 1  it doesnt matter they still keep open communic...
# 23                 1  I believe its because I am the friend that has...
# 24                 1               no anything i owe i always pay back
# 25                 1             perhaps they are tired of being asked
# 26                 1                               no im not currently
# 27                 1  I also think sometimes to myself that they don...
# 28                 1                                 yes i dont qualify
# 29                 1                 I'm nervous about asking them why
# ...              ...                                                ...
# 19959           1297        I guess so. I want to have a good career.\n
# 19960           1297  I think it's a common problem, but I don't fee...
# 19961           1297  That's a good idea. I feel more productive in ...
# 19962           1297                                I might try that.\n
# 19963           1297     Yes, drinking water helps with concentration.
# 19964           1298                                            Hello\n
# 19965           1298          I am a little down today.  How are you?\n
# 19966           1298  My friends, who I also work with, are upset wi...
# 19967           1298                  I am sad that they are upset.  \n
# 19968           1298  I am going to miss them, but yes... I am happy...
# 19969           1298                         Honestly I don't know.  \n
# 19970           1298  I think I would feel alot better about it if m...
# 19971           1298                                            Maybe\n
# 19972           1298  Well we already have a group chat... we could ...
# 19973           1298  And lunch a few times a month would be nice, b...
# 19974           1298     Yes.  We won't even be awake at the same time.
# 19975           1298                              That is a good idea\n
# 19976           1298            I will at my new job but they do not.\n
# 19977           1298                                      Yes, thanks\n
# 19978           1299                                                 hi
# 19979           1299                                      i'm nereida\n
# 19980           1299               i am in disputed mod with my friends
# 19981           1299  I explained my personal problems but they are ...
# 19982           1299  They need more money from me, but i couldn't  ...
# 19983           1299  I want to speak with them because they are in ...
# 19984           1299  Yes, i want to do some moderate friendship wit...
# 19985           1299  I want to do some help to them but i don't do ...
# 19986           1299  Yes, some disappointments show us about real f...
# 19987           1299  Sure, it is my new way of relationship to me w...
# 19988           1299                            Great, thank you friend
#
#        Lexical Diversity
# 0               1.200000
# 1               3.481481
# 2               3.565217
# 3               5.000000
# 4               3.565217
# 5               4.000000
# 6               2.850000
# 7               3.043478
# 8               3.086957
# 9               1.705882
# 10              2.050000
# 11              1.866667
# 12              1.000000
# 13              2.666667
# 14              1.428571
# 15              3.000000
# 16              1.933333
# 17              2.818182
# 18              1.000000
# 19              5.000000
# 20              1.100000
# 21              7.250000
# 22              3.631579
# 23              4.761905
# 24              2.117647
# 25              2.235294
# 26              1.666667
# 27              4.130435
# 28              1.285714
# 29              1.700000
# ...                  ...
# 19959           2.333333
# 19960           2.583333
# 19961           2.458333
# 19962           1.500000
# 19963           2.300000
# 19964           1.200000
# 19965           2.105263
# 19966           3.392857
# 19967           2.133333
# 19968           3.565217
# 19969           1.562500
# 19970           3.200000
# 19971           1.000000
# 19972           3.434783
# 19973           4.480000
# 19974           2.555556
# 19975           1.666667
# 19976           2.000000
# 19977           1.090909
# 19978           1.000000
# 19979           1.200000
# 19980           2.117647
# 19981           3.428571
# 19982           3.090909
# 19983           2.714286
# 19984           3.058824
# 19985           3.045455
# 19986           4.000000
# 19987           2.947368
# 19988           1.437500
#
# [19989 rows x 3 columns]

# %%
lexical_diversity_df = seeker_df.groupby('ConversationID')['Seeker Dialog'].apply(lambda x: lexical_diversity(x.tolist())).reset_index()
lexical_diversity_df.rename(columns={'Seeker Dialog': 'Lexical Diversity'}, inplace=True)

# %%
lexical_diversity_df
# Out:
#       ConversationID  Lexical Diversity
# 0                  0           1.000000
# 1                  1           1.000000
# 2                  2           1.000000
# 3                  3           1.000000
# 4                  4           1.000000
# 5                  5           1.000000
# 6                  6           1.000000
# 7                  7           1.000000
# 8                  8           1.000000
# 9                  9           1.000000
# 10                10           1.000000
# 11                11           1.000000
# 12                12           1.000000
# 13                13           1.000000
# 14                14           1.000000
# 15                15           1.000000
# 16                16           1.000000
# 17                17           1.000000
# 18                18           1.000000
# 19                19           1.000000
# 20                20           1.000000
# 21                21           1.000000
# 22                22           1.000000
# 23                23           1.000000
# 24                24           1.000000
# 25                25           1.000000
# 26                26           1.000000
# 27                27           1.000000
# 28                28           1.000000
# 29                29           1.000000
# ...              ...                ...
# 1270            1270           1.000000
# 1271            1271           1.000000
# 1272            1272           1.000000
# 1273            1273           1.000000
# 1274            1274           1.000000
# 1275            1275           1.000000
# 1276            1276           1.000000
# 1277            1277           1.000000
# 1278            1278           1.000000
# 1279            1279           1.000000
# 1280            1280           1.055556
# 1281            1281           1.000000
# 1282            1282           1.000000
# 1283            1283           1.000000
# 1284            1284           1.000000
# 1285            1285           1.000000
# 1286            1286           1.000000
# 1287            1287           1.000000
# 1288            1288           1.000000
# 1289            1289           1.000000
# 1290            1290           1.000000
# 1291            1291           1.000000
# 1292            1292           1.000000
# 1293            1293           1.000000
# 1294            1294           1.000000
# 1295            1295           1.000000
# 1296            1296           1.000000
# 1297            1297           1.000000
# 1298            1298           1.000000
# 1299            1299           1.000000
#
# [1300 rows x 2 columns]
